# %%
import pandas as pd

# %%
train_df = pd.read_csv(r"C:\Users\Acer\Desktop\hack4\minihackv2-train.csv")
train_df
# Out:
#         patient   time   label  epoch    EEG-Fz     EEG-0     EEG-1     EEG-2  \
# 0             1 -0.100  tongue      8 -1.681412  2.245496 -0.158350  1.163765
# 1             1 -0.096  tongue      8  0.420417  0.587559  1.650510  0.970672
# 2             1 -0.092  tongue      8  0.551365  1.499758  0.121302  2.859433
# 3             1 -0.088  tongue      8  3.054916 -1.807238  1.843603  2.286812
# 4             1 -0.084  tongue      8  2.506710 -2.453101  0.221178  0.127278
# ...         ...    ...     ...    ...       ...       ...       ...       ...
# 173659        3  0.684    foot    605 -0.853041  0.365784  2.063500 -0.469928
# 173660        3  0.688    foot    605  0.500830  4.112233  2.147840 -0.141448
# 173661        3  0.692    foot    605  0.460879  7.880876  0.789530  1.185789
# 173662        3  0.696    foot    605  1.433003  5.386203  0.199154  0.937210
# 173663        3  0.700    foot    605  3.852215  9.905024  5.352741  1.891578
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
time = train_df["time"]
sig  = train_df["EEG-0"]
# Out:
# 0         2.245496
# 1         0.587559
# 2         1.499758
# 3        -1.807238
# 4        -2.453101
#             ...
# 173659    0.365784
# 173660    4.112233
# 173661    7.880876
# 173662    5.386203
# 173663    9.905024
# Name: EEG-0, Length: 173664, dtype: float64

# %%
import matplotlib.pyplot as plt
time = train_df["time"]
sig  = train_df["EEG-0"]
plt.figure(figsize=(20,4))
plt.grid(alpha=0.3)
plt.plot(time,sig)

# %% [markdown]
# การ Explore และ Visualize data
# การทำความเข้าใจ Data ที่ได้รับรวมถึงการนำ Data ทั้ง 4 แบบจากที่โจทย์ให้มา plot เพื่อให้คนอื่นๆเข้าใจได้ง่ายๆ
#
# การเตรียมข้อมูลสำหรับการวิเคราะห์และการการใช้ Filter แบบต่างๆ lowpass, hightpass, bandpass, notchpass Filter
# การกำจัดสัญญานที่ไม่พึ่งประสงค์ เช่น ต้องการแค่ความถี่ 1-30 Hz หรือ ไม่ต้องการความถี่บางช่วงเช่น 50 Hz ก็สามารถกำจัดได้โดยการแปลง Time domain ให้กลายเป็น Frequency Domain
# การทำงานร่วมกับไฟล์ประภท .npy
# เทคนิค ICA
# Up/Down Sampling สัญญาน
# Forier transfrom, Wavelet transform
# การใช้ Braindecode library รวมถึงการใช้งาน Model แบบต่างๆ
